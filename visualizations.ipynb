# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
no_country2 = pd.read_csv('no_country_clip2_gazepoints.csv')

# %%
no_country2['subject'].unique()
# Out:
# array(['B1', 'B10', 'B11', 'B12', 'B13', 'B14', 'B15', 'B16', 'B17',
#        'B18', 'B19', 'B2', 'B20', 'B21', 'B3', 'B4', 'B5', 'B6', 'B7',
#        'B8', 'B9'], dtype=object)

# %%
no_country2.tail()
# Out:
#        Unnamed: 0  frame_num  shot_num        x        y  timestamp subject  \
# 68461     1839275       1344        14  0.55271  0.44748   56018438      B9
# 68462     1839276       1344        14  0.54846  0.43609   56034803      B9
# 68463     1839277       1344        14  0.54845  0.43666   56051201      B9
# 68464     1839278       1345        14  0.54560  0.43472   56067702      B9
# 68465     1839279       1345        14  0.54429  0.42964   56087247      B9
#
#        eyetracker_valid  in_frame  subject_valid_for_clip              film
# 68461                 1         1                       1  no_country_clip2
# 68462                 1         1                       1  no_country_clip2
# 68463                 1         1                       1  no_country_clip2
# 68464                 1         1                       1  no_country_clip2
# 68465                 1         1                       1  no_country_clip2

# %%
no_country2 = no_country2[no_country2['eyetracker_valid'] == 1]

# %%
no_country2.tail(20)
# Out:
#        Unnamed: 0  frame_num  shot_num        x        y  timestamp subject  \
# 68446     1839260       1338        14  0.55587  0.52009   55771881      B9
# 68447     1839261       1338        14  0.55905  0.49551   55788362      B9
# 68448     1839262       1338        14  0.55925  0.48643   55804885      B9
# 68449     1839263       1339        14  0.55994  0.47183   55821094      B9
# 68450     1839264       1339        14  0.56234  0.45226   55841412      B9
# 68451     1839265       1340        14  0.56246  0.44770   55853981      B9
# 68452     1839266       1340        14  0.56136  0.44413   55870496      B9
# 68453     1839267       1340        14  0.55918  0.46416   55886905      B9
# 68454     1839268       1341        14  0.55924  0.46125   55903459      B9
# 68455     1839269       1341        14  0.59188  0.46547   55919836      B9
# 68456     1839270       1342        14  0.58698  0.44349   55936204      B9
# 68457     1839271       1342        14  0.58674  0.44820   55952682      B9
# 68458     1839272       1342        14  0.57117  0.44369   55969400      B9
# 68459     1839273       1343        14  0.55962  0.42709   55985510      B9
# 68460     1839274       1343        14  0.55956  0.42957   56001997      B9
# 68461     1839275       1344        14  0.55271  0.44748   56018438      B9
# 68462     1839276       1344        14  0.54846  0.43609   56034803      B9
# 68463     1839277       1344        14  0.54845  0.43666   56051201      B9
# 68464     1839278       1345        14  0.54560  0.43472   56067702      B9
# 68465     1839279       1345        14  0.54429  0.42964   56087247      B9
#
#        eyetracker_valid  in_frame  subject_valid_for_clip              film
# 68446                 1         1                       1  no_country_clip2
# 68447                 1         1                       1  no_country_clip2
# 68448                 1         1                       1  no_country_clip2
# 68449                 1         1                       1  no_country_clip2
# 68450                 1         1                       1  no_country_clip2
# 68451                 1         1                       1  no_country_clip2
# 68452                 1         1                       1  no_country_clip2
# 68453                 1         1                       1  no_country_clip2
# 68454                 1         1                       1  no_country_clip2
# 68455                 1         1                       1  no_country_clip2
# 68456                 1         1                       1  no_country_clip2
# 68457                 1         1                       1  no_country_clip2
# 68458                 1         1                       1  no_country_clip2
# 68459                 1         1                       1  no_country_clip2
# 68460                 1         1                       1  no_country_clip2
# 68461                 1         1                       1  no_country_clip2
# 68462                 1         1                       1  no_country_clip2
# 68463                 1         1                       1  no_country_clip2
# 68464                 1         1                       1  no_country_clip2
# 68465                 1         1                       1  no_country_clip2

# %%
# f,ax = figure(figsize=(20, 10), dpi=80)
# f, ax = plt.subplots()

figure(figsize=(20, 10), dpi=80)
ax.set(xlim=(0, 1), ylim=(0, 1))

plt.scatter(x_values, y_values)

# %%
# put in extension for fname
def make_scatter(df, fname):
    x_val = np.array(df['x'])
    y_val = np.array(df['y'])
    
    f, ax = plt.subplots() # make figure
    ax.set(xlim=(0, 1), ylim=(0, 1))
    plt.scatter(x_val, y_val)
#     plt.savefig(fname)

# %%
def make_scatter2(df, fname):
    x_val = np.array(df['x'])
    y_val = np.array(df['y'])
    
    f, ax = plt.subplots() # make figure
#     ax.set(xlim=(0, 1), ylim=(0, 1))
    plt.scatter(x_val, y_val)
#     plt.savefig(fname)

# %%
make_scatter(no_country2[0:1], "plt.png")

# %%
x_values = np.array(no_country2['x'])[0:30]

# %%
y_values = np.array(no_country2['y'])[0:30]

# %%
# f,ax = figure(figsize=(20, 10), dpi=80)
f, ax = plt.subplots()

ax.set(xlim=(0, 1), ylim=(0, 1))

plt.scatter(x_values, y_values)

# %%
make_scatter(no_country2[0:7], "whole.png")

# %%
make_scatter2(no_country2[0:7], "whole.png")

# %%
nc_B2 = no_country2[no_country2['subject'] == 'B2']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2799 entries, 36779 to 39728
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2799 non-null   int64
#  1   frame_num               2799 non-null   int64
#  2   shot_num                2799 non-null   int64
#  3   x                       2799 non-null   float64
#  4   y                       2799 non-null   float64
#  5   timestamp               2799 non-null   int64
#  6   subject                 2799 non-null   object
#  7   eyetracker_valid        2799 non-null   int64
#  8   in_frame                2799 non-null   int64
#  9   subject_valid_for_clip  2799 non-null   int64
#  10  film                    2799 non-null   object
# dtypes: float64(2), int64(7), object(2)
# memory usage: 262.4+ KB

# %%
nc_B2.head(100)
# Out:
#        Unnamed: 0  frame_num  shot_num         x         y  timestamp subject  \
# 36779     1807593         59         1  0.466275  0.299315    2423975      B2
# 36780     1807594         59         1  0.454395  0.193035    2440389      B2
# 36781     1807595         59         1  0.453840  0.202566    2456842      B2
# 36782     1807596         60         1  0.439381  0.294583    2476247      B2
# 36783     1807597         60         1  0.442614  0.329881    2489744      B2
# ...           ...        ...       ...       ...       ...        ...     ...
# 36875     1807689        102         1  0.409274  0.262945    4214737      B2
# 36876     1807690        102         1  0.408838  0.254378    4231136      B2
# 36877     1807691        102         1  0.398970  0.294390    4247567      B2
# 36878     1807692        103         1  0.409909  0.297094    4264047      B2
# 36879     1807693        103         1  0.410147  0.301816    4280436      B2
#
#        eyetracker_valid  in_frame  subject_valid_for_clip              film
# 36779                 1         1                       1  no_country_clip2
# 36780                 1         1                       1  no_country_clip2
# 36781                 1         1                       1  no_country_clip2
# 36782                 1         1                       1  no_country_clip2
# 36783                 1         1                       1  no_country_clip2
# ...                 ...       ...                     ...               ...
# 36875                 1         1                       1  no_country_clip2
# 36876                 1         1                       1  no_country_clip2
# 36877                 1         1                       1  no_country_clip2
# 36878                 1         1                       1  no_country_clip2
# 36879                 1         1                       1  no_country_clip2
#
# [100 rows x 11 columns]

# %%
make_scatter(nc_B2[0:100], "B2.png")
